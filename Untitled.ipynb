# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('cleaned_data.xlsx')

# %%
df.head()
# Out:
#                      Timestamp                      Email Address  Gender  \
# 0  2022-09-11T12:45:39.4750000           aniket.gupta@hkcp.edu.in    Male
# 1  2022-09-11T12:46:00.7160000         abhishukla198826@gmail.com    Male
# 2  2022-09-11T12:47:31.7310000  Tejalsandeepsankpal2001@gmail.com  Female
# 3  2022-09-11T12:48:17.2740000           ladvivek132000@gmail.com    Male
# 4  2022-09-11T12:49:01.3280000                harshsune@gmail.com    Male
#
#   Age (In years)  Are you a 0 or a 1?  Marital Status    City  \
# 0  18 - 21 years                    0               1  Mumbai
# 1  21 - 25 years                    1               0  Mumbai
# 2  21 - 25 years                    0               0   Thane
# 3  21 - 25 years                    0               0  Kalyan
# 4  18 - 21 years                    0               0  Mumbai
#
#    How 4 do you use alarms for waking up?  How do you feel in the morning?  \
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Email Address', 'Gender', 'Age (In years)',
#        'Are you a 0 or a 1?', 'Marital Status', 'City',
#        'How 4 do you use alarms for waking up?',
#        'How do you feel in the morning?',
#        'How often do you feel groggy(dazed,weak or unsteady) in a day?',
#        'How often do you face discomforts related to sleep (nightmares, sleep walking, etc.)',
#        'Do you consume any medication which helps you fall asleep?',
#        'Do you consume any medication which interferes or affects your ability to fall asleep?',
#        'What is the temperature of the room when you sleep?',
#        'How long does it take for you to fall asleep?',
#        'How many hours do you sleep daily on an average?',
#        'How 4 do you snore at night?',
#        'Do you wake up in the middle of the night?',
#        'If yes, how long is it before you fall asleep again?_x000D_\n',
#        'How long do you nap during the day?', 'Do you smoke?',
# ...

# %%
data = df[['Best_Sleep_Imp', 'Constant_BT_Imp', 'Enough_Sleep_Imp',
       'Ideal_Env_Imp', 'Best_Sleep_Perf', 'Constant_BT_Perf',
       'Enough_Sleep_Perf', 'Ideal_Env_Perf',]]
data.head()
data1 = data.copy()

# %%
data.head()
# Out:
#    Best_Sleep_Imp Constant_BT_Imp Enough_Sleep_Imp   Ideal_Env_Imp  \
# 0         Neutral         Neutral          Neutral         Neutral
# 1  Strongly agree         Neutral   Strongly agree         Neutral
# 2           Agree  Strongly agree   Strongly agree  Strongly agree
# 3           Agree  Strongly agree   Strongly agree  Strongly agree
# 4           Agree           Agree   Strongly agree           Agree
#
#   Best_Sleep_Perf Constant_BT_Perf Enough_Sleep_Perf  Ideal_Env_Perf
# 0         Neutral          Neutral           Neutral         Neutral
# 1           Agree         Disagree          Disagree        Disagree
# 2           Agree   Strongly agree    Strongly agree  Strongly agree
# 3           Agree            Agree           Neutral        Disagree
# 4         Neutral            Agree             Agree           Agree

# %%
data.to_excel('Imp_vs_Perf.xlsx')

# %%
data.replace({"Strongly disagree":1,"Disagree":1,"Neutral":2,"Agree":3,"Strongly agree":3},inplace = True)
# Out:
# C:\Users\laksh\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head()
# Out:
#    Best_Sleep_Imp  Constant_BT_Imp  Enough_Sleep_Imp  Ideal_Env_Imp  \
# 0               3                3                 3              3
# 1               5                3                 5              3
# 2               4                5                 5              5
# 3               4                5                 5              5
# 4               4                4                 5              4
#
#    Best_Sleep_Perf  Constant_BT_Perf  Enough_Sleep_Perf  Ideal_Env_Perf
# 0                3                 3                  3               3
# 1                4                 2                  2               2
# 2                4                 5                  5               5
# 3                4                 4                  3               2
# 4                3                 4                  4               4

# %%
data1.head()
# Out:
#    Best_Sleep_Imp Constant_BT_Imp Enough_Sleep_Imp   Ideal_Env_Imp  \
# 0         Neutral         Neutral          Neutral         Neutral
# 1  Strongly agree         Neutral   Strongly agree         Neutral
# 2           Agree  Strongly agree   Strongly agree  Strongly agree
# 3           Agree  Strongly agree   Strongly agree  Strongly agree
# 4           Agree           Agree   Strongly agree           Agree
#
#   Best_Sleep_Perf Constant_BT_Perf Enough_Sleep_Perf  Ideal_Env_Perf
# 0         Neutral          Neutral           Neutral         Neutral
# 1           Agree         Disagree          Disagree        Disagree
# 2           Agree   Strongly agree    Strongly agree  Strongly agree
# 3           Agree            Agree           Neutral        Disagree
# 4         Neutral            Agree             Agree           Agree

# %%
plt.figure(figsize=(16,8))
plt.plot(data1['Best_Sleep_Imp'], label = "Importance of best sleep")
plt.plot(data1['Best_Sleep_Perf'], label = "Performace of best sleep")

# %%
fig = px.line(data1, x = data1['Best_Sleep_Imp'])
fig += px.line(data1, y = 'Best_Sleep_Perf')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18844/3575181315.py in <module>
#       1 fig = px.line(data1, x = data1['Best_Sleep_Imp'])
# ----> 2 fig += px.line(data1, y = 'Best_Sleep_Perf')
#       3 fig.show()
#
# TypeError: unsupported operand type(s) for +=: 'Figure' and 'Figure'

# %%
# Best Sleep Imp VS Perf
plt.figure(figsize=(24,8))
plt.plot(data1['Best_Sleep_Imp'], '-r', label = 'Expected')
plt.plot(data1['Best_Sleep_Perf'],'o-g', label = 'Actual')
plt.title("Best Sleep Expectation VS Best Sleep Performance", loc = "center")
plt.xlabel("No of Individuals")
plt.ylabel("Scale of Agreement")
plt.legend(loc="upper right")
plt.show()

# %%
data_agrx`ee = data[['Best_Sleep_Imp']>=4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18844/2384817278.py in <module>
# ----> 1 data_agree = data[['Best_Sleep_Imp']>=4]
#
# TypeError: '>=' not supported between instances of 'list' and 'int'
